# %% [markdown]
# ### Data Collecting:

# %%
import requests # used to send HTTP requests to web servers
from bs4 import BeautifulSoup # parsing HTML and XML documents
import pandas as pd # powerful data manipulation and analysis library
import numpy as np # used for numerical computations in Python

# %% [markdown]
# #### 1 - Web Scraping:

# %% [markdown]
# we have decided to collect data from Amazon's bestseller Books by applying web scraping for two pages ( each one contain around 50 books )

# %% [markdown]
# ##### using web Scraping codes from bestsellers books in Amazon

# %%
no_pages = 2
def get_data(pageNo):
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", 
               "Accept-Encoding":"gzip, deflate", 
               "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", 
               "DNT":"1", "Connection":"close", 
               "Upgrade-Insecure-Requests":"1"}

    r = requests.get(f'https://www.amazon.sa/-/en/gp/bestsellers/books/ref=zg_bs_pg_1_books?ie=UTF8&pg={pageNo}&language=en&crid=1MSN01VVU9GYY&qid=1711400365&rnid=12463048031&sprefix=engl+book%2Cstripbooks%2C312&ref=sr_pg_{pageNo}', headers=headers)
    content = r.content
    soup = BeautifulSoup(content, "html.parser")

    alls = []
    for d in soup.findAll('div', attrs={'class':'zg-grid-general-faceout'}): 
        name = d.find('div', attrs={'class':'_cDEzb_p13n-sc-css-line-clamp-1_1Fn1y'})
        price = d.find('span', attrs={'class':'_cDEzb_p13n-sc-price_3mJ9Z'})
        rating = d.find('span', attrs={'class':'a-icon-alt'})
        users_rated = d.find('span', attrs={'aria-hidden':'true'})
        author = d.find('div', attrs={'class':'a-row'})
        format_type = d.find('span', attrs={'class':'a-text-normal'})
        genre = d.find('div', attrs={'class':'a-row a-size-base a-color-base'})
        cover_image = d.find('img', attrs={'class': 'a-dynamic-image p13n-sc-dynamic-image p13n-product-image'})

        all1 = []

        if name is not None:
            all1.append(name.text)
        else:
            all1.append("Null")

        if price is not None:
            all1.append(price.text)
        else:
            all1.append("Null")

        if rating is not None:
            all1.append(rating.text)
        else:
            all1.append("Null")

        if users_rated is not None:
            all1.append(users_rated.text)
        else:
            all1.append("Null")

        if author is not None:
            all1.append(author.text)
        else:
            all1.append("Null")

        if format_type is not None:
            all1.append(format_type.text)
        else:
            all1.append("Null")

        if genre is not None:
            all1.append(genre.text)
        else:
            all1.append("Null")

        if cover_image is not None:
            all1.append(cover_image['src'])
        else:
            all1.append("No Image")

        alls.append(all1)
    books = soup.findAll('div', attrs={'class': 'zg-grid-general-faceout'})
    print(f"Books found : {len(books)}")
    return alls

# %%
results = []
for i in range(1, no_pages+1):
    results.append(get_data(i))
flatten = lambda l: [item for sublist in l for item in sublist]
df = pd.DataFrame(flatten(results), columns=[
    'Title',          
    'Price',         
    'Rating',          
    'Num Of Reviews', 
    'Author',         
    'Book Type',      
    'Genre',     
    'Cover Image'     
])
# Out:
# Books found : 30
# Books found : 30

# %% [markdown]
# We notice here that only 30 books have been extacted from each page out of 50 , could be due to server blocking . that's why we decided to collect other books using an extension for web scraping from google chrome .

# %% [markdown]
# - Web scraper - free web scraping : https://chromewebstore.google.com/detail/web-scraper-free-web-scra/jnhgnonknehpejjnehehllkliplmbmhn?hl=en

# %%
# checking how it looks like 
df.head(100)
# Out:
#                                                 Title       Price  \
# 0                     كتاب التحصيلي علمي 46-47 (2025)   SAR 98.00
# 1   El Sharq library المعاصر 9 تاسيس كمي 2/1 ورقي ...  SAR 107.58
# 2   Coloriages mystères Disney Princesses: Colorie...  SAR 109.10
# 3   My First Library : Boxset Of 10 Board Books Fo...   SAR 47.00
# 4                                                Null   SAR 65.00
# 5                                         فاتتني صلاة   SAR 26.00
# 6   Atomic Habits: An Easy & Proven Way to Build G...   SAR 89.00
# 7               Golden Books The Tale of Peter Rabbit    SAR 9.00
# 8                                        White Nights   SAR 19.00
# 9   The Psychology of Money: Timeless Lessons on W...   SAR 55.00
# 10  My First 365 Coloring Book: Jumbo Coloring Boo...   SAR 29.00
# 11  Surrounded By Idiots: The Four Types Of Human ...   SAR 54.26
# 12  The Let Them Theory: A Life-Changing Tool That...  SAR 159.00
# 13                               Crime and Punishment   SAR 49.00
# 14               Coloriages Mystères Disney Portraits  SAR 109.10
# 15                                       I Can Do It!   SAR 46.45
# 16  Colouring Books For Kids (Pack Of 12 Books For...   SAR 44.51
# 17  My First Book Of Patterns Pencil Control: Prac...   SAR 14.01
# 18                     الاطلس المصور للاطفال - العالم   SAR 29.00
# 19                           Llama Llama Nighty-Night   SAR 29.00
# 20  "Unlock Level 3 Listening, Speaking & Critical...   SAR 99.00
# 21  Fingerprint! Publishing The Art of War (Deluxe...   SAR 35.48
# 22                     PENGUIN Llama Llama I Love You   SAR 29.00
# 23                  Preschool Tracing And Pen Control   SAR 25.00
# 24  Dog Man: Big Jim Begins: A Graphic Novel (Dog Man   SAR 82.00
# 25                          Coloriages mystères Pixar  SAR 109.10
# 26                The Power of your Subconscious Mind   SAR 35.00
# 27  101 Unicorn Colouring Book: Fun Activity Colou...   SAR 22.16
# 28           Creative Haven Main Street Coloring Book   SAR 35.00
# 29  The Usborne Little Children'S Activity Book: M...   SAR 45.00
# 30                                       Blue Sisters   SAR 66.06
# 31                           The Life Of A Stupid Man   SAR 19.00
# 32                               د.محمد جبريل الزيلعي   SAR 46.00
# 33                            Letters to a Young Poet   SAR 33.90
# 34                                               Null   SAR 35.00
# 35  The Amazing Planet Earth (Storybots) (Step Int...   SAR 25.00
# 36  The Ballad of Never After: the stunning sequel...   SAR 54.00
# 37                                    No Longer Human   SAR 59.00
# 38           DK Children Baby Touch And Feel Mealtime   SAR 29.00
# 39  A Court Of Thorns And Roses: The #1 Bestsellin...   SAR 69.04
# 40  Cambridge University Press Unlock Level 3 Read...  SAR 126.00
# 41                       Good Vibes Coloring Book: 13   SAR 35.00
# 42   My First 1000 Words: Early Learning Picture Book   SAR 24.18
# 43                               The Naturals: Book 1   SAR 70.00
# 44               The Berenstain Bears and Too Much TV   SAR 25.00
# 45  Crown Books for Young Readers Hello, World! My...   SAR 35.00
# 46  Diary Of A Wimpy Kid - The Last Straw By Jeff ...   SAR 29.00
# 47                      Ladybird Tales: Puss in Boots    SAR 9.00
# 48      Creative Haven Dazzling Dresses Coloring Book   SAR 35.00
# 49                         ايكيجاي السر الياباني لعيش   SAR 48.99
# 50                سلسلة الاخلاق الحميدة - انا لا اخاف   SAR 29.00
# 51                                      Iron Flame: 2   SAR 89.08
# 52  A Court of Thorns and Roses Paperback Box Set ...  SAR 292.00
# 53  Think And Grow Rich: The Landmark Bestseller N...   SAR 44.00
# 54  The Coming Wave: Technology, Power, and the Tw...   SAR 62.00
# 55                                             IKIGAI   SAR 67.89
# 56                      الاطلس المصور للاطفال - الكون   SAR 26.22
# 57  My First Flash Cards Alphabet : 30 Early Learn...   SAR 25.93
# 58                                 Look Inside a Farm   SAR 69.99
# 59  Dog Man: For Whom The Ball Rolls: From The Cre...   SAR 47.47
#
#                 Rating Num Of Reviews                              Author  \
# 0   4.3 out of 5 stars              9  Nasser bin Abdulaziz Al-Abdulkarim
# 1   4.5 out of 5 stars            226                        عماد الجزيري
# 2   4.7 out of 5 stars          5,863                       Jérémy Mariez
# 3   4.6 out of 5 stars         80,669                  Wonder House Books
# 4   4.7 out of 5 stars         12,574           4.7 out of 5 stars 12,574
# 5   4.7 out of 5 stars            301                          اسلام جمال
# 6   4.8 out of 5 stars         73,014                         James Clear
# 7   4.8 out of 5 stars          1,893                      Beatrix Potter
# 8   4.6 out of 5 stars          1,509                  Fyodor Dostoyevsky
# 9   4.7 out of 5 stars         20,443                       Morgan Housel
# 10  4.5 out of 5 stars          1,621                  Wonder House Books
# 11  4.6 out of 5 stars          7,336                      Thomas Erikson
# 12  4.8 out of 5 stars            610                         Mel Robbins
# 13  4.6 out of 5 stars          2,724                  Fyodor Dostoyevsky
# 14  4.6 out of 5 stars          4,841             Christophe-Alexis Perez
# 15  4.5 out of 5 stars            205                       Trish Holland
# 16  4.4 out of 5 stars          5,353                  Wonder House Books
# 17  4.5 out of 5 stars         29,045                  Wonder House Books
# 18  4.5 out of 5 stars            127                  مجموعة من المؤلفين
# 19  4.8 out of 5 stars          3,243                        Anna Dewdney
# 20  4.3 out of 5 stars             22                        Nancy Jordan
# 21  4.7 out of 5 stars          6,887                             Sun Tzu
# 22  4.8 out of 5 stars         11,363                        Anna Dewdney
# 23  4.8 out of 5 stars          1,540                 Highlights Learning
# 24  4.9 out of 5 stars          1,491                          Dav Pilkey
# 25  4.7 out of 5 stars          2,606                       Jérémy Mariez
# 26  4.5 out of 5 stars         14,115                       Joseph Murphy
# 27  4.6 out of 5 stars          2,315                  Wonder House Books
# 28  4.7 out of 5 stars          2,469                    Teresa Goodridge
# 29  4.7 out of 5 stars          1,358                      James Maclaine
# 30  4.3 out of 5 stars            162                        Coco Mellors
# 31  4.6 out of 5 stars            233                 Ryunosuke Akutagawa
# 32                Null           Null                د.محمد جبريل الزيلعي
# 33  4.6 out of 5 stars          1,438                  Rainer Maria Rilke
# 34  4.5 out of 5 stars             25               4.5 out of 5 stars 25
# 35  4.8 out of 5 stars          2,866                           Storybots
# 36  4.8 out of 5 stars          2,619                    Stephanie Garber
# 37  4.7 out of 5 stars         13,656                         Osamu Dazai
# 38  4.5 out of 5 stars            312                                  DK
# 39  4.8 out of 5 stars         26,689                       Sarah J. Maas
# 40  4.7 out of 5 stars             18                   Carolyn Westbrook
# 41  4.7 out of 5 stars          7,387                    Thaneeya McArdle
# 42  4.5 out of 5 stars          9,377                  Wonder House Books
# 43  4.7 out of 5 stars          1,153                Jennifer Lynn Barnes
# 44  4.9 out of 5 stars          1,757                     Stan Berenstain
# 45  4.7 out of 5 stars          3,118                       Jill McDonald
# 46  4.8 out of 5 stars          9,479                         Jeff Kinney
# 47  4.3 out of 5 stars             29                      Vera Southgate
# 48  4.6 out of 5 stars            638              Eileen Rudisill Miller
# 49  4.5 out of 5 stars             21                            Ken Mogi
# 50  4.5 out of 5 stars             42                  مجموعة من المؤلفين
# 51  4.6 out of 5 stars         12,932                      Rebecca Yarros
# 52  4.7 out of 5 stars          5,464                       Sarah J. Maas
# 53  4.7 out of 5 stars         30,629                       Napoleon Hill
# 54  4.4 out of 5 stars            884                    Mustafa Suleyman
# 55  4.6 out of 5 stars         42,127                       Héctor García
# 56  4.0 out of 5 stars             40                  مجموعة من المؤلفين
# 57  4.4 out of 5 stars          2,242                  Wonder House Books
# 58  4.8 out of 5 stars            192                        Katie Daynes
# 59  4.9 out of 5 stars         24,335                          Dav Pilkey
#
#                 Book Type Genre  \
# 0               Paperback  Null
# 1               Paperback  Null
# 2               Paperback  Null
# 3              Board book  Null
# 4               Paperback  Null
# 5         Unknown Binding  Null
# 6               Hardcover  Null
# 7               Hardcover  Null
# 8   Mass Market Paperback  Null
# 9               Paperback  Null
# 10              Paperback  Null
# 11              Paperback  Null
# 12              Hardcover  Null
# 13              Paperback  Null
# 14              Paperback  Null
# 15              Hardcover  Null
# 16              Paperback  Null
# 17              Paperback  Null
# 18              Hardcover  Null
# 19             Board book  Null
# 20              Paperback  Null
# 21              Hardcover  Null
# 22             Board book  Null
# 23              Paperback  Null
# 24              Hardcover  Null
# 25              Paperback  Null
# 26              Paperback  Null
# 27              Paperback  Null
# 28              Paperback  Null
# 29              Paperback  Null
# 30              Paperback  Null
# 31  Mass Market Paperback  Null
# 32              Paperback  Null
# 33              Paperback  Null
# 34              Hardcover  Null
# 35              Paperback  Null
# 36              Paperback  Null
# 37              Paperback  Null
# 38             Board book  Null
# 39              Paperback  Null
# 40              Paperback  Null
# 41              Paperback  Null
# 42              Paperback  Null
# 43              Paperback  Null
# 44              Paperback  Null
# 45             Board book  Null
# 46              Paperback  Null
# 47              Hardcover  Null
# 48              Paperback  Null
# 49              Paperback  Null
# 50              Hardcover  Null
# 51              Hardcover  Null
# 52              Paperback  Null
# 53              Paperback  Null
# 54              Paperback  Null
# 55              Hardcover  Null
# 56              Paperback  Null
# 57                  Cards  Null
# 58             Board book  Null
# 59              Hardcover  Null
#
#                                           Cover Image
# 0   https://images-eu.ssl-images-amazon.com/images...
# 1   https://images-eu.ssl-images-amazon.com/images...
# 2   https://images-eu.ssl-images-amazon.com/images...
# 3   https://images-eu.ssl-images-amazon.com/images...
# 4   https://images-eu.ssl-images-amazon.com/images...
# 5   https://images-eu.ssl-images-amazon.com/images...
# 6   https://images-eu.ssl-images-amazon.com/images...
# 7   https://images-eu.ssl-images-amazon.com/images...
# 8   https://images-eu.ssl-images-amazon.com/images...
# 9   https://images-eu.ssl-images-amazon.com/images...
# 10  https://images-eu.ssl-images-amazon.com/images...
# 11  https://images-eu.ssl-images-amazon.com/images...
# 12  https://images-eu.ssl-images-amazon.com/images...
# 13  https://images-eu.ssl-images-amazon.com/images...
# 14  https://images-eu.ssl-images-amazon.com/images...
# 15  https://images-eu.ssl-images-amazon.com/images...
# 16  https://images-eu.ssl-images-amazon.com/images...
# 17  https://images-eu.ssl-images-amazon.com/images...
# 18  https://images-eu.ssl-images-amazon.com/images...
# 19  https://images-eu.ssl-images-amazon.com/images...
# 20  https://images-eu.ssl-images-amazon.com/images...
# 21  https://images-eu.ssl-images-amazon.com/images...
# 22  https://images-eu.ssl-images-amazon.com/images...
# 23  https://images-eu.ssl-images-amazon.com/images...
# 24  https://images-eu.ssl-images-amazon.com/images...
# 25  https://images-eu.ssl-images-amazon.com/images...
# 26  https://images-eu.ssl-images-amazon.com/images...
# 27  https://images-eu.ssl-images-amazon.com/images...
# 28  https://images-eu.ssl-images-amazon.com/images...
# 29  https://images-eu.ssl-images-amazon.com/images...
# 30  https://images-eu.ssl-images-amazon.com/images...
# 31  https://images-eu.ssl-images-amazon.com/images...
# 32  https://images-eu.ssl-images-amazon.com/images...
# 33  https://images-eu.ssl-images-amazon.com/images...
# 34  https://images-eu.ssl-images-amazon.com/images...
# 35  https://images-eu.ssl-images-amazon.com/images...
# 36  https://images-eu.ssl-images-amazon.com/images...
# 37  https://images-eu.ssl-images-amazon.com/images...
# 38  https://images-eu.ssl-images-amazon.com/images...
# 39  https://images-eu.ssl-images-amazon.com/images...
# 40  https://images-eu.ssl-images-amazon.com/images...
# 41  https://images-eu.ssl-images-amazon.com/images...
# 42  https://images-eu.ssl-images-amazon.com/images...
# 43  https://images-eu.ssl-images-amazon.com/images...
# 44  https://images-eu.ssl-images-amazon.com/images...
# 45  https://images-eu.ssl-images-amazon.com/images...
# 46  https://images-eu.ssl-images-amazon.com/images...
# 47  https://images-eu.ssl-images-amazon.com/images...
# 48  https://images-eu.ssl-images-amazon.com/images...
# 49  https://images-eu.ssl-images-amazon.com/images...
# 50  https://images-eu.ssl-images-amazon.com/images...
# 51  https://images-eu.ssl-images-amazon.com/images...
# 52  https://images-eu.ssl-images-amazon.com/images...
# 53  https://images-eu.ssl-images-amazon.com/images...
# 54  https://images-eu.ssl-images-amazon.com/images...
# 55  https://images-eu.ssl-images-amazon.com/images...
# 56  https://images-eu.ssl-images-amazon.com/images...
# 57  https://images-eu.ssl-images-amazon.com/images...
# 58  https://images-eu.ssl-images-amazon.com/images...
# 59  https://images-eu.ssl-images-amazon.com/images...

# %% [markdown]
# since the genre column is inside each book's page , we had to collect them manually

# %% [markdown]
# *results might be diffrent since we have collected them few days ago and amazon's bestseller books might have changed a bit*

# %%
# to save the data as a csv file
df.to_csv("amazon_raw_books.csv", index=False)
